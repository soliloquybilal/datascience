# %% [markdown]
# 2k22/CSE/131
# ---
# Muhammad Bilal Abid Rajput

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/content/drive/MyDrive/Mobile price.csv'
df = pd.read_csv(path)
df.head()
# Out:
#      Brand  Price
# 0    Apple    999
# 1  Samsung   1199
# 2  OnePlus    899
# 3   Xiaomi    279
# 4   Google    799

# %%
df.shape
# Out:
# (196, 2)

# %%
df.dtypes
# Out:
# Brand    object
# Price     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Brand', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=196, step=1)

# %%
df[['Brand','Price']]
# Out:
#        Brand Price
# 0      Apple   999
# 1    Samsung  1199
# 2    OnePlus   899
# 3     Xiaomi   279
# 4     Google   799
# ..       ...   ...
# 402  Samsung  1049
# 403   Xiaomi   349
# 404    Apple  1099
# 405     Oppo   429
# 406  Samsung   649
#
# [407 rows x 2 columns]

# %%
df.Price.min()
# Out:
# 99

# %%
df.Price.mean()
# Out:
# 508.8979591836735

# %%
df.describe()
# Out:
#              Price
# count   196.000000
# mean    508.897959
# std     339.800831
# min      99.000000
# 25%     239.000000
# 50%     399.000000
# 75%     699.000000
# max    1999.000000

# %%
df["Brand"].value_counts()
# Out:
# Brand
# Samsung     39
# Xiaomi      32
# Apple       29
# Oppo        25
# OnePlus     13
# Realme      12
# Huawei      12
# Vivo        10
# Nokia        9
# Motorola     9
# Google       6
# Name: count, dtype: int64

# %%
df["Brand"].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Xiaomi', 'Google', 'Oppo', 'Vivo',
#        'Realme', 'Huawei', 'Nokia', 'Motorola'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Brand    0
# Price    0
# dtype: int64

# %%
list = ["Samsung","Apple","OnePlus","Xiaomi","Google","Oppo","Vivo","Realme","Huawei","Nokia","Motorola"]

# %%
Oneplus = df[df["Brand"] == "Oneplus"]
Xiaomi = df[df["Brand"] == "Xiaomi"]
apple = df[df["Brand"] == "apple"]
Google = df[df["Brand"] == "Google"]
Oppo = df[df["Brand"] == "Oppo"]
Vivo= df[df["Brand"] == "Vivo"]
Realme = df[df["Brand"] == "Realme"]
samsung = df[df["Brand"] == "samsung"]
Huawei= df[df["Brand"] == "Huawei"]
Nokia = df[df["Brand"] == "Realme"]
Motorola = df[df["Brand"] == "Motorola"]

# %%
del Oneplus["Brand"]
del Xiaomi["Brand"]
del apple["Brand"]
del Google["Brand"]
del Oppo["Brand"]
del Vivo["Brand"]
del Realme["Brand"]
del samsung["Brand"]
del Huawei["Brand"]
del Nokia["Brand"]
del Motorola["Brand"]

# %%
Oneplus.columns = ["Oneplus"]
apple.columns = ["apple"]
Xiaomi.columns = ["Xiaomi"]
Google.columns = ["Google"]
Oppo.columns = ["Oppo"]
Vivo.columns = ["Vivo"]
samsung.columns = ["samsung"]
Realme.columns = ["Realme"]
Huawei.columns = ["Huawei"]
Nokia.columns = ["Nokia"]
Motorola.columns = ["Motorola"]

# %%
Oneplus.columns = ["Oneplus"]
apple.columns = ["apple"]
Xiaomi.columns = ["Xiaomi"]
Google.columns = ["Google"]
Oppo.columns = ["Oppo"]
Realme.columns = ["Realme"]
Huawei.columns = ["Huawei"]
samsung.columns = ["samsung"]
Nokia.columns = ["Nokia"]
Motorola.columns = ["Motorola"]
Vivo.columns = ["Vivo"]

# %%
Oneplus.reset_index(drop = False, inplace = True)
apple.reset_index(drop = False, inplace = True)
Xiaomi.reset_index(drop = False, inplace = True)
Google.reset_index(drop = False, inplace = True)
Oppo.reset_index(drop = False, inplace = True)
Realme.reset_index(drop = False, inplace = True)
Huawei.reset_index(drop = False, inplace = True)
samsung.reset_index(drop = False, inplace = True)
Motorola.reset_index(drop = False, inplace = True)
Nokia.reset_index(drop = False, inplace = True)
Vivo.reset_index(drop = False, inplace = True)

# %%
dataframes = [Oneplus, apple, Xiaomi, Google, Oppo, Realme, Huawei, samsung, Motorola, Nokia, Vivo]

mobiles = pd.concat(dataframes, axis=1, ignore_index=True)

print("Number of columns after concatenation:", mobiles.shape[1])

drop_indices = [0, 2, 4, 6, 8, 10, 12, 14]
mobiles.drop(mobiles.columns[drop_indices], axis=1, inplace=True)
print("Number of columns after dropping:", mobiles.shape[1])

new_column_names = ["Samsung", "Apple", "OnePlus", "Xiaomi", "Google", "Oppo", "Vivo", "Realme", "Huawei", "Nokia", "Motorola", "Column12", "Column13", "Column14"]
mobiles.columns = new_column_names
print(mobiles.dtypes)
mobiles.isnull().sum()
# Out:
# Number of columns after concatenation: 22
# Number of columns after dropping: 14
# Samsung     float64
# Apple       float64
# OnePlus       int64
# Xiaomi      float64
# Google      float64
# Oppo        float64
# Vivo        float64
# Realme      float64
# Huawei      float64
# Nokia       float64
# Motorola    float64
# Column12    float64
# Column13    float64
# Column14    float64
# dtype: object
# Samsung     32
# Apple       32
# OnePlus      0
# Xiaomi      26
# Google       7
# Oppo        20
# Vivo        20
# Realme      32
# Huawei      23
# Nokia       23
# Motorola    20
# Column12    20
# Column13    22
# Column14    22
# dtype: int64

# %%
# Drop specific columns by their indices
drop_indices = [0, 2, 4, 6, 8, 10, 12, 14]  # Adjust this list if needed
mobiles.drop(mobiles.columns[drop_indices], axis=1, inplace=True)
mobiles.columns = l
# Print the number of columns after dropping
print("Number of columns after dropping:", mobiles.shape[1])
# Out:
# Number of columns after dropping: 25

# %%
mobiles = mobiles.apply(pd.to_numeric, errors = "coerce")
mobiles.dtypes
# Out:
# Samsung     float64
# Apple       float64
# OnePlus       int64
# Xiaomi      float64
# Google      float64
# Oppo        float64
# Vivo        float64
# Realme      float64
# Huawei      float64
# Nokia       float64
# Motorola    float64
# Column12    float64
# Column13    float64
# Column14    float64
# dtype: object

# %%
mobiles.min()
# Out:
# Samsung       NaN
# Apple         NaN
# OnePlus     119.0
# Xiaomi      499.0
# Google      159.0
# Oppo         99.0
# Vivo        199.0
# Realme        NaN
# Huawei       88.0
# Nokia       199.0
# Motorola     12.0
# Column12     99.0
# Column13      9.0
# Column14    139.0
# dtype: float64

# %%
mobiles.max()
# Out:
# Samsung        NaN
# Apple          NaN
# OnePlus      749.0
# Xiaomi       799.0
# Google      1199.0
# Oppo         329.0
# Vivo        1399.0
# Realme         NaN
# Huawei       189.0
# Nokia        329.0
# Motorola     184.0
# Column12     329.0
# Column13      75.0
# Column14    1199.0
# dtype: float64

# %%
mobiles_data = mobiles.describe()
mobiles_data
# Out:
#        Samsung  Apple     OnePlus      Xiaomi       Google        Oppo  \
# count      0.0    0.0   32.000000    6.000000    25.000000   12.000000
# mean       NaN    NaN  287.125000  699.000000   467.000000  208.166667
# std        NaN    NaN  145.811135  109.544512   263.818119   74.523740
# min        NaN    NaN  119.000000  499.000000   159.000000   99.000000
# 25%        NaN    NaN  199.000000  699.000000   299.000000  154.000000
# 50%        NaN    NaN  249.000000  699.000000   399.000000  194.000000
# 75%        NaN    NaN  329.000000  774.000000   659.000000  261.500000
# max        NaN    NaN  749.000000  799.000000  1199.000000  329.000000
#
#               Vivo  Realme      Huawei       Nokia    Motorola
# count    12.000000     0.0    9.000000    9.000000   12.000000
# mean    783.166667     NaN  139.222222  240.111111   54.250000
# std     404.665032     NaN   34.553501   49.860918   45.754533
# min     199.000000     NaN   88.000000  199.000000   12.000000
# ...

# %%
mobiles_data.drop(["count","std","25%","50%","75%"], axis = 0, inplace = True)
mobiles_data
# Out:
#       Samsung  Apple  OnePlus  Xiaomi  Google        Oppo         Vivo  \
# mean      NaN    NaN  287.125   699.0   467.0  208.166667   783.166667
# min       NaN    NaN  119.000   499.0   159.0   99.000000   199.000000
# max       NaN    NaN  749.000   799.0  1199.0  329.000000  1399.000000
#
#       Realme      Huawei       Nokia  Motorola
# mean     NaN  139.222222  240.111111     54.25
# min      NaN   88.000000  199.000000     12.00
# max      NaN  189.000000  329.000000    184.00

# %%
min = mobiles_data.loc["min"].tolist()
max = mobiles_data.loc["max"].tolist()
mean = mobiles_data.loc["mean"].tolist()

# %%
plt.figure(figsize=(10, 4))
width = 0.6
plt.title("Minimum, Maximum And Average Prices Of Mobiles By Brand")
plt.bar(list,max,width, color = 'b', label = 'Maximum Price')
plt.bar(list,mean,width, color = 'y', label = "Average Price")
plt.bar(list,min,width, color = 'r', label = 'Minimum Price')
plt.xlabel("Brands")
plt.ylabel("Price in $")
plt.ylim(top = 2000)
plt.legend()
plt.show()
